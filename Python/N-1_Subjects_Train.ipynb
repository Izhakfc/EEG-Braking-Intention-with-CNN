# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %% [markdown]
# # **Load the data of all 12 subjects but subject number n**
#
# *   The data used in this examples was first preprocessed separately in Matlab using FieldTrip toolbox
# *   The correct input shape for tensorflow backend is **(sample_number,sample_size,channel_number)**.

# %%
import scipy.io as sio
Samples = sio.loadmat('ALL_X_BUT1.mat')
X_test = sio.loadmat('Xtrain_S1_alltrials.mat')
Y_test = sio.loadmat('Labels.mat')
Xtest = X_test['Xtrain']
Ytest = Y_test['Y1']
Labels = sio.loadmat('Labelle.mat')
X = Samples['ALL_X_BUT1']
Y = Labels['no1']

# %%
X = X.swapaxes(0, 2)
Xtest = Xtest.swapaxes(0, 2)
Ytest = Ytest.swapaxes(0,1)
Y = Y.swapaxes(0,1)
print(X.shape)
print(Y.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (2590, 376, 28)
# (2590, 1)
# (252, 376, 28)
# (252, 1)

# %%
#No subject 2
import scipy.io as sio
Samples = sio.loadmat('ALL_X_BUT2.mat')
X_test2 = sio.loadmat('Xtrain_S2_alltrials.mat')
Y_test = sio.loadmat('Labels.mat')
Xtest2 = X_test2['Xtrain']
Ytest2 = Y_test['Y2']
Labels = sio.loadmat('Labelle.mat')
X2 = Samples['ALL_X_BUT2']
Y2 = Labels['no2']

# %%
X2 = X2.swapaxes(0, 2)
Y2 = Y2.swapaxes(0,1)
Xtest2 = Xtest2.swapaxes(0, 2)
Ytest2 = Ytest2.swapaxes(0,1)
print(X2.shape)
print(Y2.shape)
print(Xtest2.shape)
print(Ytest2.shape)
# Out:
# (2638, 376, 28)
# (2638, 1)
# (204, 376, 28)
# (204, 1)

# %%
#No subject 3
import scipy.io as sio
Samples = sio.loadmat('ALL_X_BUT3.mat')
X_test3 = sio.loadmat('Xtrain_S3_alltrials.mat')
Y_test = sio.loadmat('Labels.mat')
Xtest3 = X_test3['Xtrain']
Ytest3 = Y_test['Y3']
Labels = sio.loadmat('Labelle.mat')
X3 = Samples['ALL_X_BUT3']
Y3 = Labels['no3']

# %%
X3 = X3.swapaxes(0, 2)
Y3 = Y3.swapaxes(0,1)
Xtest3 = Xtest3.swapaxes(0, 2)
Ytest3 = Ytest3.swapaxes(0,1)
print(X3.shape)
print(Y3.shape)
print(Xtest3.shape)
print(Ytest3.shape)
# Out:
# (2634, 376, 28)
# (2634, 1)
# (208, 376, 28)
# (208, 1)

# %%
#No subject 4
import scipy.io as sio
Samples = sio.loadmat('ALL_X_BUT4.mat')
X_test4 = sio.loadmat('Xtrain_S4_alltrials.mat')
Y_test = sio.loadmat('Labels.mat')
Xtest4 = X_test4['Xtrain']
Ytest4 = Y_test['Y4']
Labels = sio.loadmat('Labelle.mat')
X4 = Samples['ALL_X_BUT4']
Y4 = Labels['no4']

# %%
X4 = X4.swapaxes(0, 2)
Y4 = Y4.swapaxes(0,1)
Xtest4 = Xtest4.swapaxes(0, 2)
Ytest4 = Ytest4.swapaxes(0,1)
print(X4.shape)
print(Y4.shape)
print(Xtest4.shape)
print(Ytest4.shape)
# Out:
# (2616, 376, 28)
# (2616, 1)
# (226, 376, 28)
# (226, 1)

# %%
#No subject 5
import scipy.io as sio
Samples = sio.loadmat('ALL_X_BUT5.mat')
X_test5 = sio.loadmat('Xtrain_S5_alltrials.mat')
Y_test = sio.loadmat('Labels.mat')
Xtest5 = X_test5['Xtrain']
Ytest5 = Y_test['Y5']
Labels = sio.loadmat('Labelle.mat')
X5 = Samples['ALL_X_BUT5']
Y5 = Labels['no5']

# %%
X5 = X5.swapaxes(0, 2)
Y5 = Y5.swapaxes(0,1)
Xtest5 = Xtest5.swapaxes(0, 2)
Ytest5 = Ytest5.swapaxes(0,1)
print(X5.shape)
print(Y5.shape)
print(Xtest5.shape)
print(Ytest5.shape)
# Out:
# (2618, 376, 28)
# (2618, 1)
# (224, 376, 28)
# (224, 1)

# %%
#No subject 6
import scipy.io as sio
Samples = sio.loadmat('ALL_X_BUT6.mat')
X_test6 = sio.loadmat('Xtrain_S6_alltrials.mat')
Y_test = sio.loadmat('Labels.mat')
Xtest6 = X_test6['Xtrain']
Ytest6 = Y_test['Y6']
Labels = sio.loadmat('Labelle.mat')
X6 = Samples['ALL_X_BUT6']
Y6 = Labels['no6']

# %%
X6 = X6.swapaxes(0, 2)
Y6 = Y6.swapaxes(0,1)
Xtest6 = Xtest6.swapaxes(0, 2)
Ytest6 = Ytest6.swapaxes(0,1)
print(X6.shape)
print(Y6.shape)
print(Xtest6.shape)
print(Ytest6.shape)
# Out:
# (2608, 376, 28)
# (2608, 1)
# (234, 376, 28)
# (234, 1)

# %%
#No subject 7
import scipy.io as sio
Samples = sio.loadmat('ALL_X_BUT7.mat')
X_test7 = sio.loadmat('Xtrain_S7_alltrials.mat')
Y_test = sio.loadmat('Labels.mat')
Xtest7 = X_test7['Xtrain']
Ytest7 = Y_test['Y7']
Labels = sio.loadmat('Labelle.mat')
X7 = Samples['ALL_X_BUT7']
Y7 = Labels['no7']

# %%
X7 = X7.swapaxes(0, 2)
Y7 = Y7.swapaxes(0,1)
Xtest7 = Xtest7.swapaxes(0, 2)
Ytest7 = Ytest7.swapaxes(0,1)
print(X7.shape)
print(Y7.shape)
print(Xtest7.shape)
print(Ytest7.shape)
# Out:
# (2594, 376, 28)
# (2594, 1)
# (248, 376, 28)
# (248, 1)

# %%
#No subject 8
import scipy.io as sio
Samples = sio.loadmat('ALL_X_BUT8.mat')
X_test8 = sio.loadmat('Xtrain_S8_alltrials.mat')
Y_test = sio.loadmat('Labels.mat')
Xtest8 = X_test8['Xtrain']
Ytest8 = Y_test['Y8']
Labels = sio.loadmat('Labelle.mat')
X8 = Samples['ALL_X_BUT8']
Y8 = Labels['no8']

# %%
X8 = X8.swapaxes(0, 2)
Y8 = Y8.swapaxes(0,1)
Xtest8 = Xtest8.swapaxes(0, 2)
Ytest8 = Ytest8.swapaxes(0,1)
print(X8.shape)
print(Y8.shape)
print(Xtest8.shape)
print(Ytest8.shape)
# Out:
# (2600, 376, 28)
# (2600, 1)
# (242, 376, 28)
# (242, 1)

# %%
#No subject 9
import scipy.io as sio
Samples = sio.loadmat('ALL_X_BUT9.mat')
X_test9 = sio.loadmat('Xtrain_S9_alltrials.mat')
Y_test = sio.loadmat('Labels.mat')
Xtest9 = X_test9['Xtrain']
Ytest9 = Y_test['Y9']
Labels = sio.loadmat('Labelle.mat')
X9 = Samples['ALL_X_BUT9']
Y9 = Labels['no9']

# %%
X9 = X9.swapaxes(0, 2)
Y9 = Y9.swapaxes(0,1)
Xtest9 = Xtest9.swapaxes(0, 2)
Ytest9 = Ytest9.swapaxes(0,1)
print(X9.shape)
print(Y9.shape)
print(Xtest9.shape)
print(Ytest9.shape)
# Out:
# (2576, 376, 28)
# (2576, 1)
# (266, 376, 28)
# (266, 1)

# %%
#No subject 10
import scipy.io as sio
Samples = sio.loadmat('ALL_X_BUT10.mat')
X_test10 = sio.loadmat('Xtrain_S10_alltrials.mat')
Y_test = sio.loadmat('Labels.mat')
Xtest10 = X_test10['Xtrain']
Ytest10 = Y_test['Y10']
Labels = sio.loadmat('Labelle.mat')
X10 = Samples['ALL_X_BUT10']
Y10 = Labels['no10']

# %%
X10 = X10.swapaxes(0, 2)
Y10 = Y10.swapaxes(0,1)
Xtest10 = Xtest10.swapaxes(0, 2)
Ytest10 = Ytest10.swapaxes(0,1)
print(X10.shape)
print(Y10.shape)
print(Xtest10.shape)
print(Ytest10.shape)
# Out:
# (2594, 376, 28)
# (2594, 1)
# (248, 376, 28)
# (248, 1)

# %%
#No subject 11
import scipy.io as sio
Samples = sio.loadmat('ALL_X_BUT11.mat')
X_test11 = sio.loadmat('Xtrain_S11_alltrials.mat')
Y_test = sio.loadmat('Labels.mat')
Xtest11 = X_test11['Xtrain']
Ytest11 = Y_test['Y11']
Labels = sio.loadmat('Labelle.mat')
X11 = Samples['ALL_X_BUT11']
Y11 = Labels['no11']

# %%
X11 = X11.swapaxes(0, 2)
Y11 = Y11.swapaxes(0,1)
Xtest11 = Xtest11.swapaxes(0, 2)
Ytest11 = Ytest11.swapaxes(0,1)
print(X11.shape)
print(Y11.shape)
print(Xtest11.shape)
print(Ytest11.shape)
# Out:
# (2594, 376, 28)
# (2594, 1)
# (248, 376, 28)
# (248, 1)

# %%
#No subject 12
import scipy.io as sio
Samples = sio.loadmat('ALL_X_BUT12.mat')
X_test12 = sio.loadmat('Xtrain_S12_alltrials.mat')
Y_test = sio.loadmat('Labels.mat')
Xtest12 = X_test12['Xtrain']
Ytest12 = Y_test['Y12']
Labels = sio.loadmat('Labelle.mat')
X12 = Samples['ALL_X_BUT12']
Y12 = Labels['no12']

# %%
X12 = X12.swapaxes(0, 2)
Y12 = Y12.swapaxes(0,1)
Xtest12 = Xtest12.swapaxes(0, 2)
Ytest12 = Ytest12.swapaxes(0,1)
print(X12.shape)
print(Y12.shape)
print(Xtest12.shape)
print(Ytest12.shape)
# Out:
# (2600, 376, 28)
# (2600, 1)
# (242, 376, 28)
# (242, 1)

# %%
num_classes = 2

# %%
print(num_classes)
# Out:
# 2

# %% [markdown]
# # **Create a CNN model**
#
# The designed model for this classification was as follows:
#
#
# *   A 1D convolutional layer with kernel size of 3 yielding 64 filters.
# *   A Batch Normalization layer.
# *   A ReLu layer.
# *   A dropout layer.
#
# This layering order was repeated three times. After this a global average pooling layer gets the average for the channels of each trial. Finally a dense layer acting as a fully connected layer was placed in the CNN architecture with a sigmoig activation function.
#
# For this test, the CNN model was trained using the data from all n-1 subjects and tested with the one left-out subject, this process was repeated and tested with all 12 subjects.

# %%
model = None

# %%
input_shape =(376,28)
def cnn_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)
    conv1 = keras.layers.Dropout(.2)(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)
    conv2 = keras.layers.Dropout(.2)(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)
    conv3 = keras.layers.Dropout(.2)(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(1, activation="sigmoid")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = cnn_model(input_shape=X.shape[1:])
keras.utils.plot_model(model, show_shapes=True)

# %%
idx = np.random.permutation(len(X))
X = X[idx]
Y = Y[idx]

# %%
epochs = 50
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "All-1_Model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    #loss = "sparse_categorical_crossentropy",
    loss="binary_crossentropy",
    metrics=["accuracy",keras.metrics.TruePositives(name='tp'),
           keras.metrics.FalsePositives(name='fp'),
           keras.metrics.TrueNegatives(name='tn'),
           keras.metrics.FalseNegatives(name='fn')]
)
history = model.fit(
    X,
    Y,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.1,
    verbose=1,
)
# Out:
# Epoch 1/50
# 73/73 [==============================] - 10s 136ms/step - loss: 0.6813 - accuracy: 0.5521 - tp: 360.0000 - fp: 241.0000 - tn: 927.0000 - fn: 803.0000 - val_loss: 0.7520 - val_accuracy: 0.5521 - val_tp: 111.0000 - val_fp: 95.0000 - val_tn: 32.0000 - val_fn: 21.0000
# Epoch 2/50
# 73/73 [==============================] - 9s 121ms/step - loss: 0.6467 - accuracy: 0.5933 - tp: 514.0000 - fp: 299.0000 - tn: 869.0000 - fn: 649.0000 - val_loss: 0.7664 - val_accuracy: 0.5792 - val_tp: 64.0000 - val_fp: 41.0000 - val_tn: 86.0000 - val_fn: 68.0000
# Epoch 3/50
# 73/73 [==============================] - 9s 122ms/step - loss: 0.6322 - accuracy: 0.6156 - tp: 572.0000 - fp: 305.0000 - tn: 863.0000 - fn: 591.0000 - val_loss: 0.7702 - val_accuracy: 0.5869 - val_tp: 59.0000 - val_fp: 34.0000 - val_tn: 93.0000 - val_fn: 73.0000
# Epoch 4/50
# ...

# %%
model = keras.models.load_model("All-1_Model.h5")

test_loss, test_acc,tp,fp,tn,fn = model.evaluate(Xtest, Ytest)

print(f"Loss:{test_loss} ",f"Acc:{test_acc} ",f"True positives:{tp} ",f"False positives:{fp} ",f"True negatives:{tn} ",f"False negatives:{fn} ")
# Out:
# 8/8 [==============================] - 0s 20ms/step - loss: 0.7771 - accuracy: 0.6429 - tp: 106.0000 - fp: 70.0000 - tn: 56.0000 - fn: 20.0000
# Loss:0.7771406769752502  Acc:0.6428571343421936  True positives:106.0  False positives:70.0  True negatives:56.0  False negatives:20.0

# %%
# summarize history for accuracy no subject 1
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
idx = np.random.permutation(len(X2))
X2 = X2[idx]
Y2 = Y2[idx]

# %%
epochs = 50
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "All-2_Model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    #loss = "sparse_categorical_crossentropy",
    loss="binary_crossentropy",
    metrics=["accuracy",keras.metrics.TruePositives(name='tp'),
           keras.metrics.FalsePositives(name='fp'),
           keras.metrics.TrueNegatives(name='tn'),
           keras.metrics.FalseNegatives(name='fn')]
)
history = model.fit(
    X2,
    Y2,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.1,
    verbose=1,
)
# Out:
# Epoch 1/50
# 75/75 [==============================] - 9s 122ms/step - loss: 0.6771 - accuracy: 0.5733 - tp: 462.0000 - fp: 291.0000 - tn: 899.0000 - fn: 722.0000 - val_loss: 0.6756 - val_accuracy: 0.4886 - val_tp: 87.0000 - val_fp: 87.0000 - val_tn: 42.0000 - val_fn: 48.0000
# Epoch 2/50
# 75/75 [==============================] - 9s 121ms/step - loss: 0.6403 - accuracy: 0.6074 - tp: 543.0000 - fp: 291.0000 - tn: 899.0000 - fn: 641.0000 - val_loss: 0.6450 - val_accuracy: 0.5909 - val_tp: 49.0000 - val_fp: 22.0000 - val_tn: 107.0000 - val_fn: 86.0000
# Epoch 3/50
# 75/75 [==============================] - 9s 116ms/step - loss: 0.6256 - accuracy: 0.6285 - tp: 643.0000 - fp: 341.0000 - tn: 849.0000 - fn: 541.0000 - val_loss: 0.6496 - val_accuracy: 0.5795 - val_tp: 35.0000 - val_fp: 11.0000 - val_tn: 118.0000 - val_fn: 100.0000
# Epoch 4/50
# ...

# %%
model = keras.models.load_model("All-2_Model.h5")

test_loss, test_acc,tp,fp,tn,fn = model.evaluate(Xtest2, Ytest2)

print(f"Loss:{test_loss} ",f"Acc:{test_acc} ",f"True positives:{tp} ",f"False positives:{fp} ",f"True negatives:{tn} ",f"False negatives:{fn} ")
# Out:
# 7/7 [==============================] - 0s 18ms/step - loss: 0.7948 - accuracy: 0.5931 - tp: 28.0000 - fp: 9.0000 - tn: 93.0000 - fn: 74.0000
# Loss:0.7948000431060791  Acc:0.593137264251709  True positives:28.0  False positives:9.0  True negatives:93.0  False negatives:74.0

# %%
# summarize history for accuracy no subject 2
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
idx = np.random.permutation(len(X3))
X3 = X3[idx]
Y3 = Y3[idx]

# %%
epochs = 50
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "All-3_Model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    #loss = "sparse_categorical_crossentropy",
    loss="binary_crossentropy",
    metrics=["accuracy",keras.metrics.TruePositives(name='tp'),
           keras.metrics.FalsePositives(name='fp'),
           keras.metrics.TrueNegatives(name='tn'),
           keras.metrics.FalseNegatives(name='fn')]
)
history = model.fit(
    X3,
    Y3,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.1,
    verbose=1,
)
# Out:
# Epoch 1/50
# 75/75 [==============================] - 9s 121ms/step - loss: 0.4682 - accuracy: 0.7747 - tp: 887.0000 - fp: 233.0000 - tn: 949.0000 - fn: 301.0000 - val_loss: 0.6412 - val_accuracy: 0.6742 - val_tp: 48.0000 - val_fp: 5.0000 - val_tn: 130.0000 - val_fn: 81.0000
# Epoch 2/50
# 75/75 [==============================] - 9s 121ms/step - loss: 0.4550 - accuracy: 0.7806 - tp: 921.0000 - fp: 253.0000 - tn: 929.0000 - fn: 267.0000 - val_loss: 0.6185 - val_accuracy: 0.7083 - val_tp: 59.0000 - val_fp: 7.0000 - val_tn: 128.0000 - val_fn: 70.0000
# Epoch 3/50
# 75/75 [==============================] - 9s 118ms/step - loss: 0.4371 - accuracy: 0.7928 - tp: 895.0000 - fp: 198.0000 - tn: 984.0000 - fn: 293.0000 - val_loss: 0.5500 - val_accuracy: 0.7045 - val_tp: 61.0000 - val_fp: 10.0000 - val_tn: 125.0000 - val_fn: 68.0000
# Epoch 4/50
# ...

# %%
model = keras.models.load_model("All-3_Model.h5")

test_loss, test_acc,tp,fp,tn,fn = model.evaluate(Xtest3, Ytest3)

print(f"Loss:{test_loss} ",f"Acc:{test_acc} ",f"True positives:{tp} ",f"False positives:{fp} ",f"True negatives:{tn} ",f"False negatives:{fn} ")
# Out:
# 7/7 [==============================] - 0s 22ms/step - loss: 1.0573 - accuracy: 0.5288 - tp: 12.0000 - fp: 6.0000 - tn: 98.0000 - fn: 92.0000
# Loss:1.0572943687438965  Acc:0.5288461446762085  True positives:12.0  False positives:6.0  True negatives:98.0  False negatives:92.0

# %%
# summarize history for accuracy no subject 3
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
idx = np.random.permutation(len(X4))
X4 = X4[idx]
Y4 = Y4[idx]

# %%
epochs = 50
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "All-4_Model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    #loss = "sparse_categorical_crossentropy",
    loss="binary_crossentropy",
    metrics=["accuracy",keras.metrics.TruePositives(name='tp'),
           keras.metrics.FalsePositives(name='fp'),
           keras.metrics.TrueNegatives(name='tn'),
           keras.metrics.FalseNegatives(name='fn')]
)
history = model.fit(
    X4,
    Y4,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.1,
    verbose=1,
)
# Out:
# Epoch 1/50
# 74/74 [==============================] - 9s 122ms/step - loss: 0.4384 - accuracy: 0.7795 - tp: 906.0000 - fp: 249.0000 - tn: 929.0000 - fn: 270.0000 - val_loss: 0.4466 - val_accuracy: 0.7786 - val_tp: 88.0000 - val_fp: 14.0000 - val_tn: 116.0000 - val_fn: 44.0000
# Epoch 2/50
# 74/74 [==============================] - 9s 117ms/step - loss: 0.4144 - accuracy: 0.7986 - tp: 919.0000 - fp: 217.0000 - tn: 961.0000 - fn: 257.0000 - val_loss: 0.4433 - val_accuracy: 0.7748 - val_tp: 86.0000 - val_fp: 13.0000 - val_tn: 117.0000 - val_fn: 46.0000
# Epoch 3/50
# 74/74 [==============================] - 9s 117ms/step - loss: 0.3983 - accuracy: 0.8059 - tp: 938.0000 - fp: 219.0000 - tn: 959.0000 - fn: 238.0000 - val_loss: 0.6285 - val_accuracy: 0.6870 - val_tp: 55.0000 - val_fp: 5.0000 - val_tn: 125.0000 - val_fn: 77.0000
# Epoch 4/50
# ...

# %%
model = keras.models.load_model("All-4_Model.h5")

test_loss, test_acc,tp,fp,tn,fn = model.evaluate(Xtest4, Ytest4)

print(f"Loss:{test_loss} ",f"Acc:{test_acc} ",f"True positives:{tp} ",f"False positives:{fp} ",f"True negatives:{tn} ",f"False negatives:{fn} ")
# Out:
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3416 - accuracy: 0.8673 - tp: 83.0000 - fp: 0.0000e+00 - tn: 113.0000 - fn: 30.0000
# Loss:0.3415648937225342  Acc:0.8672566413879395  True positives:83.0  False positives:0.0  True negatives:113.0  False negatives:30.0

# %%
# summarize history for accuracy no subject 4
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
idx = np.random.permutation(len(X5))
X5 = X5[idx]
Y5 = Y5[idx]

# %%
epochs = 50
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "All-5_Model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    #loss = "sparse_categorical_crossentropy",
    loss="binary_crossentropy",
    metrics=["accuracy",keras.metrics.TruePositives(name='tp'),
           keras.metrics.FalsePositives(name='fp'),
           keras.metrics.TrueNegatives(name='tn'),
           keras.metrics.FalseNegatives(name='fn')]
)
history = model.fit(
    X5,
    Y5,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.1,
    verbose=1,
)
# Out:
# Epoch 1/50
# 74/74 [==============================] - 9s 127ms/step - loss: 0.4249 - accuracy: 0.7971 - tp: 923.0000 - fp: 222.0000 - tn: 955.0000 - fn: 256.0000 - val_loss: 0.4839 - val_accuracy: 0.7481 - val_tp: 68.0000 - val_fp: 4.0000 - val_tn: 128.0000 - val_fn: 62.0000
# Epoch 2/50
# 74/74 [==============================] - 9s 116ms/step - loss: 0.4101 - accuracy: 0.8031 - tp: 942.0000 - fp: 227.0000 - tn: 950.0000 - fn: 237.0000 - val_loss: 0.4997 - val_accuracy: 0.7519 - val_tp: 72.0000 - val_fp: 7.0000 - val_tn: 125.0000 - val_fn: 58.0000
# Epoch 3/50
# 74/74 [==============================] - 9s 118ms/step - loss: 0.4000 - accuracy: 0.8132 - tp: 932.0000 - fp: 193.0000 - tn: 984.0000 - fn: 247.0000 - val_loss: 0.5708 - val_accuracy: 0.7405 - val_tp: 65.0000 - val_fp: 3.0000 - val_tn: 129.0000 - val_fn: 65.0000
# Epoch 4/50
# ...

# %%
model = keras.models.load_model("All-5_Model.h5")

test_loss, test_acc,tp,fp,tn,fn = model.evaluate(Xtest5, Ytest5)

print(f"Loss:{test_loss} ",f"Acc:{test_acc} ",f"True positives:{tp} ",f"False positives:{fp} ",f"True negatives:{tn} ",f"False negatives:{fn} ")
# Out:
# 7/7 [==============================] - 0s 20ms/step - loss: 0.2895 - accuracy: 0.8884 - tp: 91.0000 - fp: 4.0000 - tn: 108.0000 - fn: 21.0000
# Loss:0.28952696919441223  Acc:0.8883928656578064  True positives:91.0  False positives:4.0  True negatives:108.0  False negatives:21.0

# %%
# summarize history for accuracy no subject 5
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
idx = np.random.permutation(len(X6))
X6 = X6[idx]
Y6 = Y6[idx]

# %%
epochs = 50
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "All-6_Model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    #loss = "sparse_categorical_crossentropy",
    loss="binary_crossentropy",
    metrics=["accuracy",keras.metrics.TruePositives(name='tp'),
           keras.metrics.FalsePositives(name='fp'),
           keras.metrics.TrueNegatives(name='tn'),
           keras.metrics.FalseNegatives(name='fn')]
)
history = model.fit(
    X6,
    Y6,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.1,
    verbose=1,
)
# Out:
# Epoch 1/50
# 74/74 [==============================] - 9s 123ms/step - loss: 0.3754 - accuracy: 0.8240 - tp: 948.0000 - fp: 192.0000 - tn: 986.0000 - fn: 221.0000 - val_loss: 0.5309 - val_accuracy: 0.7778 - val_tp: 79.0000 - val_fp: 2.0000 - val_tn: 124.0000 - val_fn: 56.0000
# Epoch 2/50
# 74/74 [==============================] - 9s 116ms/step - loss: 0.3574 - accuracy: 0.8296 - tp: 944.0000 - fp: 175.0000 - tn: 1003.0000 - fn: 225.0000 - val_loss: 0.5035 - val_accuracy: 0.7701 - val_tp: 104.0000 - val_fp: 29.0000 - val_tn: 97.0000 - val_fn: 31.0000
# Epoch 3/50
# 74/74 [==============================] - 9s 117ms/step - loss: 0.3665 - accuracy: 0.8304 - tp: 955.0000 - fp: 184.0000 - tn: 994.0000 - fn: 214.0000 - val_loss: 0.5355 - val_accuracy: 0.7433 - val_tp: 80.0000 - val_fp: 12.0000 - val_tn: 114.0000 - val_fn: 55.0000
# Epoch 4/50
# ...

# %%
model = keras.models.load_model("All-6_Model.h5")

test_loss, test_acc,tp,fp,tn,fn = model.evaluate(Xtest6, Ytest6)

print(f"Loss:{test_loss} ",f"Acc:{test_acc} ",f"True positives:{tp} ",f"False positives:{fp} ",f"True negatives:{tn} ",f"False negatives:{fn} ")
# Out:
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5443 - accuracy: 0.7222 - tp: 54.0000 - fp: 2.0000 - tn: 115.0000 - fn: 63.0000
# Loss:0.5443485975265503  Acc:0.7222222089767456  True positives:54.0  False positives:2.0  True negatives:115.0  False negatives:63.0

# %%
# summarize history for accuracy no subject 6
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
idx = np.random.permutation(len(X7))
X7 = X7[idx]
Y7 = Y7[idx]

# %%
epochs = 50
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "All-7_Model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    #loss = "sparse_categorical_crossentropy",
    loss="binary_crossentropy",
    metrics=["accuracy",keras.metrics.TruePositives(name='tp'),
           keras.metrics.FalsePositives(name='fp'),
           keras.metrics.TrueNegatives(name='tn'),
           keras.metrics.FalseNegatives(name='fn')]
)
history = model.fit(
    X7,
    Y7,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.1,
    verbose=1,
)
# Out:
# Epoch 1/50
# 73/73 [==============================] - 9s 127ms/step - loss: 0.3642 - accuracy: 0.8389 - tp: 946.0000 - fp: 166.0000 - tn: 1012.0000 - fn: 210.0000 - val_loss: 0.4678 - val_accuracy: 0.7885 - val_tp: 95.0000 - val_fp: 9.0000 - val_tn: 110.0000 - val_fn: 46.0000
# Epoch 2/50
# 73/73 [==============================] - 9s 122ms/step - loss: 0.3572 - accuracy: 0.8368 - tp: 945.0000 - fp: 170.0000 - tn: 1008.0000 - fn: 211.0000 - val_loss: 0.7054 - val_accuracy: 0.6885 - val_tp: 63.0000 - val_fp: 3.0000 - val_tn: 116.0000 - val_fn: 78.0000
# Epoch 3/50
# 73/73 [==============================] - 9s 123ms/step - loss: 0.3443 - accuracy: 0.8432 - tp: 966.0000 - fp: 176.0000 - tn: 1002.0000 - fn: 190.0000 - val_loss: 0.5066 - val_accuracy: 0.7731 - val_tp: 95.0000 - val_fp: 13.0000 - val_tn: 106.0000 - val_fn: 46.0000
# Epoch 4/50
# ...

# %%
model = keras.models.load_model("All-7_Model.h5")

test_loss, test_acc,tp,fp,tn,fn = model.evaluate(Xtest7, Ytest7)

print(f"Loss:{test_loss} ",f"Acc:{test_acc} ",f"True positives:{tp} ",f"False positives:{fp} ",f"True negatives:{tn} ",f"False negatives:{fn} ")
# Out:
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7747 - accuracy: 0.6048 - tp: 52.0000 - fp: 26.0000 - tn: 98.0000 - fn: 72.0000
# Loss:0.7746506929397583  Acc:0.6048387289047241  True positives:52.0  False positives:26.0  True negatives:98.0  False negatives:72.0

# %%
# summarize history for accuracy no subject 7
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
idx = np.random.permutation(len(X8))
X8 = X8[idx]
Y8 = Y8[idx]

# %%
epochs = 50
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "All-8_Model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    #loss = "sparse_categorical_crossentropy",
    loss="binary_crossentropy",
    metrics=["accuracy",keras.metrics.TruePositives(name='tp'),
           keras.metrics.FalsePositives(name='fp'),
           keras.metrics.TrueNegatives(name='tn'),
           keras.metrics.FalseNegatives(name='fn')]
)
history = model.fit(
    X8,
    Y8,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.1,
    verbose=1,
)
# Out:
# Epoch 1/50
# 74/74 [==============================] - 9s 122ms/step - loss: 0.3292 - accuracy: 0.8551 - tp: 976.0000 - fp: 147.0000 - tn: 1025.0000 - fn: 192.0000 - val_loss: 0.4715 - val_accuracy: 0.7885 - val_tp: 88.0000 - val_fp: 11.0000 - val_tn: 117.0000 - val_fn: 44.0000
# Epoch 2/50
# 74/74 [==============================] - 8s 114ms/step - loss: 0.3209 - accuracy: 0.8568 - tp: 976.0000 - fp: 143.0000 - tn: 1029.0000 - fn: 192.0000 - val_loss: 0.5834 - val_accuracy: 0.7462 - val_tp: 71.0000 - val_fp: 5.0000 - val_tn: 123.0000 - val_fn: 61.0000
# Epoch 3/50
# 74/74 [==============================] - 9s 119ms/step - loss: 0.2866 - accuracy: 0.8722 - tp: 998.0000 - fp: 129.0000 - tn: 1043.0000 - fn: 170.0000 - val_loss: 0.7603 - val_accuracy: 0.6923 - val_tp: 58.0000 - val_fp: 6.0000 - val_tn: 122.0000 - val_fn: 74.0000
# Epoch 4/50
# ...

# %%
model = keras.models.load_model("All-8_Model.h5")

test_loss, test_acc,tp,fp,tn,fn = model.evaluate(Xtest8, Ytest8)

print(f"Loss:{test_loss} ",f"Acc:{test_acc} ",f"True positives:{tp} ",f"False positives:{fp} ",f"True negatives:{tn} ",f"False negatives:{fn} ")
# Out:
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7655 - accuracy: 0.6322 - tp: 48.0000 - fp: 16.0000 - tn: 105.0000 - fn: 73.0000
# Loss:0.7654732465744019  Acc:0.6322314143180847  True positives:48.0  False positives:16.0  True negatives:105.0  False negatives:73.0

# %%
# summarize history for accuracy no subject 8
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
idx = np.random.permutation(len(X9))
X9 = X9[idx]
Y9 = Y9[idx]

# %%
epochs = 50
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "All-9_Model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    #loss = "sparse_categorical_crossentropy",
    loss="binary_crossentropy",
    metrics=["accuracy",keras.metrics.TruePositives(name='tp'),
           keras.metrics.FalsePositives(name='fp'),
           keras.metrics.TrueNegatives(name='tn'),
           keras.metrics.FalseNegatives(name='fn')]
)
history = model.fit(
    X9,
    Y9,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.1,
    verbose=1,
)
# Out:
# Epoch 1/50
# 73/73 [==============================] - 9s 127ms/step - loss: 0.3342 - accuracy: 0.8486 - tp: 969.0000 - fp: 158.0000 - tn: 998.0000 - fn: 193.0000 - val_loss: 0.4955 - val_accuracy: 0.7946 - val_tp: 82.0000 - val_fp: 9.0000 - val_tn: 123.0000 - val_fn: 44.0000
# Epoch 2/50
# 73/73 [==============================] - 9s 120ms/step - loss: 0.3154 - accuracy: 0.8538 - tp: 992.0000 - fp: 169.0000 - tn: 987.0000 - fn: 170.0000 - val_loss: 0.8762 - val_accuracy: 0.6744 - val_tp: 42.0000 - val_fp: 0.0000e+00 - val_tn: 132.0000 - val_fn: 84.0000
# Epoch 3/50
# 73/73 [==============================] - 9s 119ms/step - loss: 0.3061 - accuracy: 0.8632 - tp: 981.0000 - fp: 136.0000 - tn: 1020.0000 - fn: 181.0000 - val_loss: 0.5736 - val_accuracy: 0.7674 - val_tp: 71.0000 - val_fp: 5.0000 - val_tn: 127.0000 - val_fn: 55.0000
# Epoch 4/50
# ...

# %%
model = keras.models.load_model("All-9_Model.h5")

test_loss, test_acc,tp,fp,tn,fn = model.evaluate(Xtest9, Ytest9)

print(f"Loss:{test_loss} ",f"Acc:{test_acc} ",f"True positives:{tp} ",f"False positives:{fp} ",f"True negatives:{tn} ",f"False negatives:{fn} ")
# Out:
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6843 - accuracy: 0.7782 - tp: 122.0000 - fp: 48.0000 - tn: 85.0000 - fn: 11.0000
# Loss:0.6843210458755493  Acc:0.7781955003738403  True positives:122.0  False positives:48.0  True negatives:85.0  False negatives:11.0

# %%
# summarize history for accuracy no subject 9
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
idx = np.random.permutation(len(X10))
X10 = X10[idx]
Y10 = Y10[idx]

# %%
epochs = 50
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "All-10_Model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    #loss = "sparse_categorical_crossentropy",
    loss="binary_crossentropy",
    metrics=["accuracy",keras.metrics.TruePositives(name='tp'),
           keras.metrics.FalsePositives(name='fp'),
           keras.metrics.TrueNegatives(name='tn'),
           keras.metrics.FalseNegatives(name='fn')]
)
history = model.fit(
    X10,
    Y10,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.1,
    verbose=1,
)
# Out:
# Epoch 1/50
# 73/73 [==============================] - 9s 126ms/step - loss: 0.3647 - accuracy: 0.8389 - tp: 977.0000 - fp: 182.0000 - tn: 981.0000 - fn: 194.0000 - val_loss: 0.3004 - val_accuracy: 0.8500 - val_tp: 107.0000 - val_fp: 20.0000 - val_tn: 114.0000 - val_fn: 19.0000
# Epoch 2/50
# 73/73 [==============================] - 9s 118ms/step - loss: 0.3229 - accuracy: 0.8603 - tp: 986.0000 - fp: 141.0000 - tn: 1022.0000 - fn: 185.0000 - val_loss: 0.4305 - val_accuracy: 0.7885 - val_tp: 71.0000 - val_fp: 0.0000e+00 - val_tn: 134.0000 - val_fn: 55.0000
# Epoch 3/50
# 73/73 [==============================] - 9s 118ms/step - loss: 0.2982 - accuracy: 0.8710 - tp: 1012.0000 - fp: 142.0000 - tn: 1021.0000 - fn: 159.0000 - val_loss: 0.3589 - val_accuracy: 0.8346 - val_tp: 91.0000 - val_fp: 8.0000 - val_tn: 126.0000 - val_fn: 35.0000
# Epoch 4/50
# ...

# %%
model = keras.models.load_model("All-10_Model.h5")

test_loss, test_acc,tp,fp,tn,fn = model.evaluate(Xtest10, Ytest10)

print(f"Loss:{test_loss} ",f"Acc:{test_acc} ",f"True positives:{tp} ",f"False positives:{fp} ",f"True negatives:{tn} ",f"False negatives:{fn} ")
# Out:
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0357 - accuracy: 0.9919 - tp: 124.0000 - fp: 2.0000 - tn: 122.0000 - fn: 0.0000e+00
# Loss:0.03568298742175102  Acc:0.9919354915618896  True positives:124.0  False positives:2.0  True negatives:122.0  False negatives:0.0

# %%
# summarize history for accuracy no subject 10
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
idx = np.random.permutation(len(X11))
X11 = X11[idx]
Y11 = Y11[idx]

# %%
epochs = 50
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "All-11_Model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    #loss = "sparse_categorical_crossentropy",
    loss="binary_crossentropy",
    metrics=["accuracy",keras.metrics.TruePositives(name='tp'),
           keras.metrics.FalsePositives(name='fp'),
           keras.metrics.TrueNegatives(name='tn'),
           keras.metrics.FalseNegatives(name='fn')]
)
history = model.fit(
    X11,
    Y11,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.1,
    verbose=1,
)
# Out:
# Epoch 1/50
# 73/73 [==============================] - 9s 123ms/step - loss: 0.2985 - accuracy: 0.8710 - tp: 1009.0000 - fp: 140.0000 - tn: 1024.0000 - fn: 161.0000 - val_loss: 0.3896 - val_accuracy: 0.8308 - val_tp: 90.0000 - val_fp: 7.0000 - val_tn: 126.0000 - val_fn: 37.0000
# Epoch 2/50
# 73/73 [==============================] - 9s 117ms/step - loss: 0.2728 - accuracy: 0.8895 - tp: 1030.0000 - fp: 118.0000 - tn: 1046.0000 - fn: 140.0000 - val_loss: 0.4147 - val_accuracy: 0.8231 - val_tp: 88.0000 - val_fp: 7.0000 - val_tn: 126.0000 - val_fn: 39.0000
# Epoch 3/50
# 73/73 [==============================] - 9s 117ms/step - loss: 0.2668 - accuracy: 0.8856 - tp: 1027.0000 - fp: 124.0000 - tn: 1040.0000 - fn: 143.0000 - val_loss: 0.5445 - val_accuracy: 0.7692 - val_tp: 74.0000 - val_fp: 7.0000 - val_tn: 126.0000 - val_fn: 53.0000
# Epoch 4/50
# ...

# %%
model = keras.models.load_model("All-11_Model.h5")

test_loss, test_acc,tp,fp,tn,fn = model.evaluate(Xtest11, Ytest11)

print(f"Loss:{test_loss} ",f"Acc:{test_acc} ",f"True positives:{tp} ",f"False positives:{fp} ",f"True negatives:{tn} ",f"False negatives:{fn} ")
# Out:
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5702 - accuracy: 0.7137 - tp: 92.0000 - fp: 39.0000 - tn: 85.0000 - fn: 32.0000
# Loss:0.570229709148407  Acc:0.7137096524238586  True positives:92.0  False positives:39.0  True negatives:85.0  False negatives:32.0

# %%
# summarize history for accuracy no subject 11
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
idx = np.random.permutation(len(X12))
X12 = X12[idx]
Y12 = Y12[idx]

# %%
epochs = 50
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "All-12_Model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    #loss = "sparse_categorical_crossentropy",
    loss="binary_crossentropy",
    metrics=["accuracy",keras.metrics.TruePositives(name='tp'),
           keras.metrics.FalsePositives(name='fp'),
           keras.metrics.TrueNegatives(name='tn'),
           keras.metrics.FalseNegatives(name='fn')]
)
history = model.fit(
    X12,
    Y12,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.1,
    verbose=1,
)
# Out:
# Epoch 1/50
# 74/74 [==============================] - 9s 122ms/step - loss: 0.2848 - accuracy: 0.8825 - tp: 1029.0000 - fp: 132.0000 - tn: 1036.0000 - fn: 143.0000 - val_loss: 0.3938 - val_accuracy: 0.8385 - val_tp: 90.0000 - val_fp: 4.0000 - val_tn: 128.0000 - val_fn: 38.0000
# Epoch 2/50
# 74/74 [==============================] - 9s 115ms/step - loss: 0.2538 - accuracy: 0.8970 - tp: 1049.0000 - fp: 118.0000 - tn: 1050.0000 - fn: 123.0000 - val_loss: 0.3864 - val_accuracy: 0.8615 - val_tp: 95.0000 - val_fp: 3.0000 - val_tn: 129.0000 - val_fn: 33.0000
# Epoch 3/50
# 74/74 [==============================] - 9s 116ms/step - loss: 0.2321 - accuracy: 0.9060 - tp: 1045.0000 - fp: 93.0000 - tn: 1075.0000 - fn: 127.0000 - val_loss: 0.2978 - val_accuracy: 0.8731 - val_tp: 103.0000 - val_fp: 8.0000 - val_tn: 124.0000 - val_fn: 25.0000
# Epoch 4/50
# ...

# %%
model = keras.models.load_model("All-12_Model.h5")

test_loss, test_acc,tp,fp,tn,fn = model.evaluate(Xtest12, Ytest12)

print(f"Loss:{test_loss} ",f"Acc:{test_acc} ",f"True positives:{tp} ",f"False positives:{fp} ",f"True negatives:{tn} ",f"False negatives:{fn} ")
# Out:
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5374 - accuracy: 0.7934 - tp: 82.0000 - fp: 11.0000 - tn: 110.0000 - fn: 39.0000
# Loss:0.5374061465263367  Acc:0.7933884263038635  True positives:82.0  False positives:11.0  True negatives:110.0  False negatives:39.0

# %%
# summarize history for accuracy no subject 12
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
